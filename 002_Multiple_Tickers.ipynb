# %% [markdown]
# <a href="https://colab.research.google.com/github/rajeshpahari/Own-Work/blob/main/002_Multiple_Tickers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multipletickers

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
symbol=['RELIANCE.BO','EXIDEIND.BO','HDFC.BO']

# %%
df=yf.download(tickers=symbol)
df
# Out:
# [*********************100%***********************]  3 of 3 completed
#              Adj Close                                 Close               \
#            EXIDEIND.BO      HDFC.BO  RELIANCE.BO EXIDEIND.BO      HDFC.BO
# Date
# 1995-07-10         NaN          NaN    16.716921         NaN          NaN
# 1995-07-11         NaN          NaN    16.716921         NaN          NaN
# 1995-07-12         NaN          NaN    17.039019         NaN          NaN
# 1995-07-13         NaN          NaN    17.006811         NaN          NaN
# 1995-07-14         NaN          NaN    17.071232         NaN          NaN
# ...                ...          ...          ...         ...          ...
# 2023-03-23  177.050003  2567.699951  2247.550049  177.050003  2567.699951
# 2023-03-24  175.199997  2563.550049  2203.500000  175.199997  2563.550049
# 2023-03-27  172.500000  2563.000000  2237.500000  172.500000  2563.000000
# 2023-03-28  173.149994  2580.449951  2247.949951  173.149994  2580.449951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6979 entries, 1995-07-10 to 2023-03-29
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   (Adj Close, EXIDEIND.BO)  5159 non-null   float64
#  1   (Adj Close, HDFC.BO)      5612 non-null   float64
#  2   (Adj Close, RELIANCE.BO)  6979 non-null   float64
#  3   (Close, EXIDEIND.BO)      5159 non-null   float64
#  4   (Close, HDFC.BO)          5612 non-null   float64
#  5   (Close, RELIANCE.BO)      6979 non-null   float64
#  6   (High, EXIDEIND.BO)       5159 non-null   float64
#  7   (High, HDFC.BO)           5612 non-null   float64
#  8   (High, RELIANCE.BO)       6979 non-null   float64
#  9   (Low, EXIDEIND.BO)        5159 non-null   float64
#  10  (Low, HDFC.BO)            5612 non-null   float64
#  11  (Low, RELIANCE.BO)        6979 non-null   float64
#  12  (Open, EXIDEIND.BO)       5159 non-null   float64
# ...

# %%
df.columns
# Out:
# MultiIndex([('Adj Close', 'EXIDEIND.BO'),
#             ('Adj Close',     'HDFC.BO'),
#             ('Adj Close', 'RELIANCE.BO'),
#             (    'Close', 'EXIDEIND.BO'),
#             (    'Close',     'HDFC.BO'),
#             (    'Close', 'RELIANCE.BO'),
#             (     'High', 'EXIDEIND.BO'),
#             (     'High',     'HDFC.BO'),
#             (     'High', 'RELIANCE.BO'),
#             (      'Low', 'EXIDEIND.BO'),
#             (      'Low',     'HDFC.BO'),
#             (      'Low', 'RELIANCE.BO'),
#             (     'Open', 'EXIDEIND.BO'),
#             (     'Open',     'HDFC.BO'),
#             (     'Open', 'RELIANCE.BO'),
#             (   'Volume', 'EXIDEIND.BO'),
#             (   'Volume',     'HDFC.BO'),
#             (   'Volume', 'RELIANCE.BO')],
#            )

# %%
df.Close.head()
# Out:
#             EXIDEIND.BO  HDFC.BO  RELIANCE.BO
# Date
# 1995-07-10          NaN      NaN    24.533884
# 1995-07-11          NaN      NaN    24.533884
# 1995-07-12          NaN      NaN    25.006599
# 1995-07-13          NaN      NaN    24.959328
# 1995-07-14          NaN      NaN    25.053869

# %%
df.loc[:,("Close","EXIDEIND.BO")].head()
# Out:
# Date
# 1995-07-10   NaN
# 1995-07-11   NaN
# 1995-07-12   NaN
# 1995-07-13   NaN
# 1995-07-14   NaN
# Name: (Close, EXIDEIND.BO), dtype: float64

# %%
df.Close['EXIDEIND.BO']
# Out:
# Date
# 1995-07-10           NaN
# 1995-07-11           NaN
# 1995-07-12           NaN
# 1995-07-13           NaN
# 1995-07-14           NaN
#                  ...
# 2023-03-23    177.050003
# 2023-03-24    175.199997
# 2023-03-27    172.500000
# 2023-03-28    173.149994
# 2023-03-29    176.949997
# Name: EXIDEIND.BO, Length: 6979, dtype: float64

# %%
df.head()
# Out:
#              Adj Close                           Close                      \
#            EXIDEIND.BO HDFC.BO RELIANCE.BO EXIDEIND.BO HDFC.BO RELIANCE.BO
# Date
# 1995-07-10         NaN     NaN   16.716921         NaN     NaN   24.533884
# 1995-07-11         NaN     NaN   16.716921         NaN     NaN   24.533884
# 1995-07-12         NaN     NaN   17.039019         NaN     NaN   25.006599
# 1995-07-13         NaN     NaN   17.006811         NaN     NaN   24.959328
# 1995-07-14         NaN     NaN   17.071232         NaN     NaN   25.053869
#
#                   High                             Low                      \
#            EXIDEIND.BO HDFC.BO RELIANCE.BO EXIDEIND.BO HDFC.BO RELIANCE.BO
# Date
# 1995-07-10         NaN     NaN   24.864784         NaN     NaN   24.439341
# 1995-07-11         NaN     NaN   24.533884         NaN     NaN   24.533884
# 1995-07-12         NaN     NaN   25.006599         NaN     NaN   24.675697
# ...

# %%
df.loc[:,(slice(None),slice('EXIDEIND.BO'))]
# Out:
#              Adj Close       Close        High         Low        Open  \
#            EXIDEIND.BO EXIDEIND.BO EXIDEIND.BO EXIDEIND.BO EXIDEIND.BO
# Date
# 1995-07-10         NaN         NaN         NaN         NaN         NaN
# 1995-07-11         NaN         NaN         NaN         NaN         NaN
# 1995-07-12         NaN         NaN         NaN         NaN         NaN
# 1995-07-13         NaN         NaN         NaN         NaN         NaN
# 1995-07-14         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2023-03-23  177.050003  177.050003  180.350006  176.199997  176.199997
# 2023-03-24  175.199997  175.199997  177.800003  174.000000  177.699997
# 2023-03-27  172.500000  172.500000  175.550003  172.050003  175.100006
# 2023-03-28  173.149994  173.149994  173.899994  170.500000  172.500000
# 2023-03-29  176.949997  176.949997  177.899994  172.550003  172.550003
#
#                 Volume
# ...

# %% [markdown]
# # Saving & Loading Data

# %%
df.to_csv(path_or_buf='/content/test.csv')

# %%
df1=pd.read_csv('/content/test.csv',header=[0,1])
df1.head()
# Out:
#   Unnamed: 0_level_0   Adj Close                           Close          \
#   Unnamed: 0_level_1 EXIDEIND.BO HDFC.BO RELIANCE.BO EXIDEIND.BO HDFC.BO
# 0               Date         NaN     NaN         NaN         NaN     NaN
# 1         1995-07-10         NaN     NaN   16.716921         NaN     NaN
# 2         1995-07-11         NaN     NaN   16.716921         NaN     NaN
# 3         1995-07-12         NaN     NaN   17.039019         NaN     NaN
# 4         1995-07-13         NaN     NaN   17.006811         NaN     NaN
#
#                      High                             Low                      \
#   RELIANCE.BO EXIDEIND.BO HDFC.BO RELIANCE.BO EXIDEIND.BO HDFC.BO RELIANCE.BO
# 0         NaN         NaN     NaN         NaN         NaN     NaN         NaN
# 1   24.533884         NaN     NaN   24.864784         NaN     NaN   24.439341
# 2   24.533884         NaN     NaN   24.533884         NaN     NaN   24.533884
# ...

# %%
df1=pd.read_csv('/content/test.csv',header=[0,1],index_col=0)
df1.head()
# Out:
#              Adj Close                           Close                      \
#            EXIDEIND.BO HDFC.BO RELIANCE.BO EXIDEIND.BO HDFC.BO RELIANCE.BO
# Date
# 1995-07-10         NaN     NaN   16.716921         NaN     NaN   24.533884
# 1995-07-11         NaN     NaN   16.716921         NaN     NaN   24.533884
# 1995-07-12         NaN     NaN   17.039019         NaN     NaN   25.006599
# 1995-07-13         NaN     NaN   17.006811         NaN     NaN   24.959328
# 1995-07-14         NaN     NaN   17.071232         NaN     NaN   25.053869
#
#                   High                             Low                      \
#            EXIDEIND.BO HDFC.BO RELIANCE.BO EXIDEIND.BO HDFC.BO RELIANCE.BO
# Date
# 1995-07-10         NaN     NaN   24.864784         NaN     NaN   24.439341
# 1995-07-11         NaN     NaN   24.533884         NaN     NaN   24.533884
# 1995-07-12         NaN     NaN   25.006599         NaN     NaN   24.675697
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6979 entries, 1995-07-10 to 2023-03-29
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   (Adj Close, EXIDEIND.BO)  5159 non-null   float64
#  1   (Adj Close, HDFC.BO)      5612 non-null   float64
#  2   (Adj Close, RELIANCE.BO)  6979 non-null   float64
#  3   (Close, EXIDEIND.BO)      5159 non-null   float64
#  4   (Close, HDFC.BO)          5612 non-null   float64
#  5   (Close, RELIANCE.BO)      6979 non-null   float64
#  6   (High, EXIDEIND.BO)       5159 non-null   float64
#  7   (High, HDFC.BO)           5612 non-null   float64
#  8   (High, RELIANCE.BO)       6979 non-null   float64
#  9   (Low, EXIDEIND.BO)        5159 non-null   float64
#  10  (Low, HDFC.BO)            5612 non-null   float64
#  11  (Low, RELIANCE.BO)        6979 non-null   float64
#  12  (Open, EXIDEIND.BO)       5159 non-null   float64
# ...

# %%
df1=pd.read_csv('/content/test.csv',header=[0,1],index_col=0,parse_dates=[0])
df1.head()
# Out:
#              Adj Close                           Close                      \
#            EXIDEIND.BO HDFC.BO RELIANCE.BO EXIDEIND.BO HDFC.BO RELIANCE.BO
# Date
# 1995-07-10         NaN     NaN   16.716921         NaN     NaN   24.533884
# 1995-07-11         NaN     NaN   16.716921         NaN     NaN   24.533884
# 1995-07-12         NaN     NaN   17.039019         NaN     NaN   25.006599
# 1995-07-13         NaN     NaN   17.006811         NaN     NaN   24.959328
# 1995-07-14         NaN     NaN   17.071232         NaN     NaN   25.053869
#
#                   High                             Low                      \
#            EXIDEIND.BO HDFC.BO RELIANCE.BO EXIDEIND.BO HDFC.BO RELIANCE.BO
# Date
# 1995-07-10         NaN     NaN   24.864784         NaN     NaN   24.439341
# 1995-07-11         NaN     NaN   24.533884         NaN     NaN   24.533884
# 1995-07-12         NaN     NaN   25.006599         NaN     NaN   24.675697
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6979 entries, 1995-07-10 to 2023-03-29
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   (Adj Close, EXIDEIND.BO)  5159 non-null   float64
#  1   (Adj Close, HDFC.BO)      5612 non-null   float64
#  2   (Adj Close, RELIANCE.BO)  6979 non-null   float64
#  3   (Close, EXIDEIND.BO)      5159 non-null   float64
#  4   (Close, HDFC.BO)          5612 non-null   float64
#  5   (Close, RELIANCE.BO)      6979 non-null   float64
#  6   (High, EXIDEIND.BO)       5159 non-null   float64
#  7   (High, HDFC.BO)           5612 non-null   float64
#  8   (High, RELIANCE.BO)       6979 non-null   float64
#  9   (Low, EXIDEIND.BO)        5159 non-null   float64
#  10  (Low, HDFC.BO)            5612 non-null   float64
#  11  (Low, RELIANCE.BO)        6979 non-null   float64
#  12  (Open, EXIDEIND.BO)       5159 non-null   float64
# ...

# %% [markdown]
# # Ticker Boject

# %%
ap=yf.Ticker(ticker='ASIANPAINT.NS')

# %%
ap
# Out:
# yfinance.Ticker object <ASIANPAINT.NS>

# %%
ap.history()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2023-02-28 00:00:00+05:30  2750.000000  2839.000000  2727.449951  2828.800049
# 2023-03-01 00:00:00+05:30  2828.000000  2853.300049  2816.050049  2840.899902
# 2023-03-02 00:00:00+05:30  2831.000000  2849.000000  2811.000000  2833.899902
# 2023-03-03 00:00:00+05:30  2837.050049  2852.000000  2810.649902  2828.850098
# 2023-03-06 00:00:00+05:30  2843.000000  2884.000000  2830.250000  2864.550049
# 2023-03-08 00:00:00+05:30  2870.000000  2870.000000  2827.000000  2859.550049
# 2023-03-09 00:00:00+05:30  2862.000000  2872.449951  2836.850098  2853.550049
# 2023-03-10 00:00:00+05:30  2844.000000  2844.000000  2807.000000  2830.199951
# 2023-03-13 00:00:00+05:30  2823.500000  2849.449951  2772.199951  2784.199951
# 2023-03-14 00:00:00+05:30  2782.949951  2786.949951  2740.050049  2745.600098
# 2023-03-15 00:00:00+05:30  2772.199951  2866.350098  2765.199951  2827.399902
# ...

# %%
ap.get_info()
# Out:
# {'symbol': 'ASIANPAINT.NS',
#  'twoHundredDayAverageChangePercent': -0.10054483,
#  'fiftyTwoWeekLowChangePercent': 0.08222656,
#  'averageAnalystRating': '3.1 - Hold',
#  'language': 'en-US',
#  'regularMarketDayRange': '2755.0 - 2793.75',
#  'earningsTimestampEnd': 1683802740,
#  'epsForward': 28.24,
#  'regularMarketDayHigh': 2793.75,
#  'twoHundredDayAverageChange': -309.698,
#  'askSize': 0,
#  'twoHundredDayAverage': 3080.198,
#  'bookValue': 147.025,
#  'marketCap': 2656466108416,
#  'fiftyTwoWeekHighChange': -812.3999,
#  'fiftyTwoWeekRange': '2560.0 - 3582.9',
#  'fiftyDayAverageChange': -28.580078,
#  'exchangeDataDelayedBy': 15,
#  'firstTradeDateMilliseconds': 1025495100000,
#  'averageDailyVolume3Month': 1064137,
#  'trailingAnnualDividendRate': 19.9,
#  'fiftyTwoWeekLow': 2560.0,
#  'market': 'in_market',
#  'regularMarketVolume': 1087391,
#  'quoteSourceName': 'Delayed Quote',
#  'messageBoardId': 'finmb_878276',
#  'priceHint': 2,
#  'exchange': 'NSI',
# ...

# %%
info=pd.Series(ap.get_info())
info
# Out:
# symbol                                      ASIANPAINT.NS
# twoHundredDayAverageChangePercent               -0.100545
# fiftyTwoWeekLowChangePercent                     0.082227
# averageAnalystRating                           3.1 - Hold
# language                                            en-US
#                                              ...
# bid                                                   0.0
# triggerable                                          True
# priceToBook                                     18.843735
# longName                             Asian Paints Limited
# trailingPegRatio                                     None
# Length: 70, dtype: object

# %%
info['priceToBook']
# Out:
# 18.843735

# %%
fast_info=pd.Series(ap.fast_info)
fast_info
# Out:
# currency                                  INR
# dayHigh                               2793.75
# dayLow                                 2755.0
# exchange                                  NSI
# fiftyDayAverage                   2804.011997
# lastPrice                              2770.5
# lastVolume                            1087648
# marketCap                     2656466220000.0
# open                              2784.449951
# previousClose                          2783.0
# quoteType                              EQUITY
# regularMarketPreviousClose        2784.449951
# shares                              958840000
# tenDayAverageVolume                   1034010
# threeMonthAverageVolume               1060461
# timezone                         Asia/Kolkata
# twoHundredDayAverage              3058.981489
# yearChange                          -0.110351
# yearHigh                          3582.899902
# yearLow                                2560.0
# dtype: object

# %%
ap.fast_info
# Out:
# lazy-loading dict with keys = ['currency', 'dayHigh', 'dayLow', 'exchange', 'fiftyDayAverage', 'lastPrice', 'lastVolume', 'marketCap', 'open', 'previousClose', 'quoteType', 'regularMarketPreviousClose', 'shares', 'tenDayAverageVolume', 'threeMonthAverageVolume', 'timezone', 'twoHundredDayAverage', 'yearChange', 'yearHigh', 'yearLow']

# %%
ap.history_metadata
# Out:
# {'currency': 'INR',
#  'symbol': 'ASIANPAINT.NS',
#  'exchangeName': 'NSI',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': Timestamp('2002-07-01 09:15:00+0530', tz='Asia/Kolkata'),
#  'regularMarketTime': Timestamp('2023-03-29 15:30:00+0530', tz='Asia/Kolkata'),
#  'gmtoffset': 19800,
#  'timezone': 'IST',
#  'exchangeTimezoneName': 'Asia/Kolkata',
#  'regularMarketPrice': 2770.5,
#  'chartPreviousClose': 2839.85,
#  'previousClose': 2784.45,
#  'scale': 3,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'end': Timestamp('2023-03-31 09:15:00+0530', tz='Asia/Kolkata'),
#    'start': Timestamp('2023-03-31 09:15:00+0530', tz='Asia/Kolkata')},
#   'regular': {'end': Timestamp('2023-03-31 15:30:00+0530', tz='Asia/Kolkata'),
#    'start': Timestamp('2023-03-31 09:15:00+0530', tz='Asia/Kolkata')},
#   'post': {'end': Timestamp('2023-03-31 15:30:00+0530', tz='Asia/Kolkata'),
#    'start': Timestamp('2023-03-31 15:30:00+0530', tz='Asia/Kolkata')}},
# ...

# %%
ap.actions
# Out:
# Empty DataFrame
# Columns: [Dividends, Stock Splits]
# Index: []

# %% [markdown]
# # Price Share Outstanding & Market Capitalization

# %%
info= pd.Series(ap.get_info())
info
# Out:
# symbol                                      ASIANPAINT.NS
# twoHundredDayAverageChangePercent               -0.100545
# fiftyTwoWeekLowChangePercent                     0.082227
# averageAnalystRating                           3.1 - Hold
# language                                            en-US
#                                              ...
# bid                                                   0.0
# triggerable                                          True
# priceToBook                                     18.843735
# longName                             Asian Paints Limited
# trailingPegRatio                                     None
# Length: 70, dtype: object

# %%
info.index
# Out:
# Index(['symbol', 'twoHundredDayAverageChangePercent',
#        'fiftyTwoWeekLowChangePercent', 'averageAnalystRating', 'language',
#        'regularMarketDayRange', 'earningsTimestampEnd', 'epsForward',
#        'regularMarketDayHigh', 'twoHundredDayAverageChange', 'askSize',
#        'twoHundredDayAverage', 'bookValue', 'marketCap',
#        'fiftyTwoWeekHighChange', 'fiftyTwoWeekRange', 'fiftyDayAverageChange',
#        'exchangeDataDelayedBy', 'firstTradeDateMilliseconds',
#        'averageDailyVolume3Month', 'trailingAnnualDividendRate',
#        'fiftyTwoWeekLow', 'market', 'regularMarketVolume', 'quoteSourceName',
#        'messageBoardId', 'priceHint', 'exchange', 'sourceInterval',
#        'regularMarketDayLow', 'region', 'shortName',
#        'fiftyDayAverageChangePercent', 'fullExchangeName',
#        'earningsTimestampStart', 'financialCurrency', 'gmtOffSetMilliseconds',
#        'regularMarketOpen', 'regularMarketTime', 'regularMarketChangePercent',
# ...

# %%
info.market
# Out:
# 'in_market'

# %%
mc=info.marketCap
mc
# Out:
# 2656466108416

# %%
shares=info.sharesOutstanding
shares
# Out:
# 958840000

# %%
price=mc/shares
price
# Out:
# 2770.4998836260484

# %% [markdown]
# # Market Value Vs Book Value

# %%
info
# Out:
# symbol                                      ASIANPAINT.NS
# twoHundredDayAverageChangePercent               -0.100545
# fiftyTwoWeekLowChangePercent                     0.082227
# averageAnalystRating                           3.1 - Hold
# language                                            en-US
#                                              ...
# bid                                                   0.0
# triggerable                                          True
# priceToBook                                     18.843735
# longName                             Asian Paints Limited
# trailingPegRatio                                     None
# Length: 70, dtype: object

# %%
price=info.marketCap/info.sharesOutstanding
price
# Out:
# 2770.4998836260484

# %%
bv=info.bookValue
bv
# Out:
# 147.025

# %%
info.priceToBook
# Out:
# 18.843735

# %%
price/bv
# Out:
# 18.843733267308608

# %%
symbol='BERGEPAINT.NS'

# %%
yf.Ticker(ticker=symbol).get_info()['priceToBook']
# Out:
# 13.570617

# %%
symbol='HDFC.BO'
yf.Ticker(ticker=symbol).get_info()['priceToBook']
# Out:
# 3.5642977

# %%
ap
# Out:
# yfinance.Ticker object <ASIANPAINT.NS>

# %%
tn=yf.Ticker(ticker='TEJASNET.BO')

# %%
#tn.get_balance_sheet()

# %%
! pip install yahooquery
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from yahooquery import Ticker
tn=Ticker('TEJASNET.BO')

# %%
bs=tn.balance_sheet().T
bs
# Out:
# symbol                                                 TEJASNET.BO  \
# asOfDate                                       2020-03-31 00:00:00
# periodType                                                     12M
# currencyCode                                                   INR
# AccountsPayable                                        747700000.0
# AccountsReceivable                                    3756300000.0
# ...                                                            ...
# TotalEquityGrossMinorityInterest                     10809400000.0
# TotalLiabilitiesNetMinorityInterest                   1602100000.0
# TotalNonCurrentAssets                                 2891100000.0
# TotalNonCurrentLiabilitiesNetMinorityInterest          225000000.0
# WorkingCapital                                        8143300000.0
#
# symbol                                                 TEJASNET.BO  \
# asOfDate                                       2021-03-31 00:00:00
# ...

# %%
# import yfinance as yf
# tnf=yf.Ticker(ticker='TEJASNET.BO')

# %%
# tnf.get_balance_sheet()

# %%
tn.income_statement().T
# Out:
# symbol                                                      TEJASNET.BO  \
# asOfDate                                            2020-03-31 00:00:00
# periodType                                                          12M
# currencyCode                                                        INR
# Amortization                                                582900000.0
# BasicAverageShares                                           92038454.0
# BasicEPS                                                         -25.76
# CostOfRevenue                                              2073500000.0
# DepreciationAndAmortizationInIncomeStatement                770500000.0
# DepreciationIncomeStatement                                 187600000.0
# DilutedAverageShares                                         92038454.0
# DilutedEPS                                                       -25.76
# DilutedNIAvailtoComStockholders                           -2371200000.0
# ...

# %%
tn.cash_flow().T
# Out:
# symbol                                      TEJASNET.BO          TEJASNET.BO  \
# asOfDate                            2020-03-31 00:00:00  2021-03-31 00:00:00
# periodType                                          12M                  12M
# currencyCode                                        INR                  INR
# AmortizationCashFlow                                NaN                  NaN
# BeginningCashPosition                       169000000.0          664800000.0
# CapitalExpenditure                         -927700000.0         -825200000.0
# CashDividendsPaid                          -110800000.0                  NaN
# ChangeInCashSupplementalAsReported          495800000.0         -136100000.0
# ChangeInInventory                          -706000000.0          383400000.0
# ChangeInOtherCurrentAssets                 -119000000.0          -78500000.0
# ChangeInOtherCurrentLiabilities            -333100000.0           86000000.0
# ...

# %%
tn.cash_flow(frequency='q')
# Out:
#               asOfDate periodType currencyCode    NetIncome
# symbol
# TEJASNET.BO 2022-03-31         3M          INR -496200000.0
# TEJASNET.BO 2022-06-30         3M          INR  -66400000.0
# TEJASNET.BO 2022-09-30         3M          INR   10700000.0
# TEJASNET.BO 2022-12-31         3M          INR -108800000.0
# TEJASNET.BO 2022-12-31        TTM          INR -660700000.0
