# %% [markdown]
# <a href="https://colab.research.google.com/github/rajeshpahari/Own-Work/blob/main/003_BSESp500_Stocks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multipletickers

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://en.wikipedia.org/wiki/BSE_SENSEX'

# %%
df=pd.read_html(url)[1]
df
# Out:
#      #  ticker Number         Symbol                        Companies  \
# 0    1         500820  ASIANPAINT.BO                     Asian Paints
# 1    2         532215    AXISBANK.BO                        Axis Bank
# 2    3         532977  BAJAJ-AUTO.BO                       Bajaj Auto
# 3    4         500034  BAJFINANCE.BO                    Bajaj Finance
# 4    5         532978  BAJAJFINSV.BO                    Bajaj Finserv
# 5    6         532454  BHARTIARTL.BO                    Bharti Airtel
# 6    7         500124     DRREDDY.BO          Dr Reddy's Laboratories
# 7    8         532281     HCLTECH.BO                 HCL Technologies
# 8    9         500010        HDFC.BO                             HDFC
# 9   10         500180    HDFCBANK.BO                        HDFC Bank
# 10  11         500696  HINDUNILVR.BO       Hindustan Unilever Limited
# 11  12         532174   ICICIBANK.BO                       ICICI Bank
# ...

# %%
symbols=df.Symbol.to_list()
symbols
# Out:
# ['ASIANPAINT.BO',
#  'AXISBANK.BO',
#  'BAJAJ-AUTO.BO',
#  'BAJFINANCE.BO',
#  'BAJAJFINSV.BO',
#  'BHARTIARTL.BO',
#  'DRREDDY.BO',
#  'HCLTECH.BO',
#  'HDFC.BO',
#  'HDFCBANK.BO',
#  'HINDUNILVR.BO',
#  'ICICIBANK.BO',
#  'INDUSINDBK.BO',
#  'INFY.BO',
#  'ITC.BO',
#  'KOTAKBANK.BO',
#  'LT.BO',
#  'M&M.BO',
#  'MARUTI.BO',
#  'NESTLEIND.BO',
#  'NTPC.BO',
#  'ONGC.BO',
#  'POWERGRID.BO',
#  'RELIANCE.BO',
#  'SBIN.BO',
#  'SUNPHARMA.BO',
#  'TCS.BO',
#  'TECHM.BO',
#  'TITAN.BO',
#  'ULTRACEMCO.BO']

# %%
ts=yf.download(tickers=symbols,start='2023-1-01',actions=True)
ts.head()
# Out:
# [*********************100%***********************]  30 of 30 completed
#                Adj Close                                          \
#            ASIANPAINT.BO AXISBANK.BO BAJAJ-AUTO.BO BAJAJFINSV.BO
# Date
# 2023-01-02   3046.350098  941.450012   3576.649902   1552.400024
# 2023-01-03   3028.500000  962.650024   3603.899902   1563.250000
# 2023-01-04   3016.050049  957.400024   3552.600098   1547.449951
# 2023-01-05   3004.899902  949.500000   3626.250000   1468.550049
# 2023-01-06   2979.300049  939.950012   3639.649902   1429.900024
#
#                                                                                \
#            BAJFINANCE.BO BHARTIARTL.BO   DRREDDY.BO   HCLTECH.BO      HDFC.BO
# Date
# 2023-01-02   6556.750000    813.599976  4237.750000  1029.871826  2652.600098
# 2023-01-03   6606.149902    817.599976  4237.700195  1031.804321  2666.449951
# 2023-01-04   6573.600098    811.400024  4254.850098  1026.799683  2625.899902
# ...

# %%
ts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 62 entries, 2023-01-02 to 2023-03-31
# Columns: 240 entries, ('Adj Close', 'ASIANPAINT.BO') to ('Volume', 'ULTRACEMCO.BO')
# dtypes: float64(210), int64(30)
# memory usage: 116.7 KB

# %%
ts.isnull().sum()
# Out:
# Adj Close  ASIANPAINT.BO    0
#            AXISBANK.BO      0
#            BAJAJ-AUTO.BO    0
#            BAJAJFINSV.BO    0
#            BAJFINANCE.BO    0
#                            ..
# Volume     SUNPHARMA.BO     0
#            TCS.BO           0
#            TECHM.BO         0
#            TITAN.BO         0
#            ULTRACEMCO.BO    0
# Length: 240, dtype: int64

# %%
ts.dropna(inplace=True)

# %%
ts.Close.iloc[-1]
# Out:
# ASIANPAINT.BO     2762.000000
# AXISBANK.BO        853.450012
# BAJAJ-AUTO.BO     3893.300049
# BAJAJFINSV.BO     1255.699951
# BAJFINANCE.BO     5628.000000
# BHARTIARTL.BO      751.500000
# DRREDDY.BO        4650.000000
# HCLTECH.BO        1087.199951
# HDFC.BO           2620.500000
# HDFCBANK.BO       1605.250000
# HINDUNILVR.BO     2537.899902
# ICICIBANK.BO       876.099976
# INDUSINDBK.BO     1073.000000
# INFY.BO           1426.400024
# ITC.BO             382.750000
# KOTAKBANK.BO      1739.650024
# LT.BO             2174.000000
# M&M.BO            1152.900024
# MARUTI.BO         8310.000000
# NESTLEIND.BO     19532.099609
# NTPC.BO            176.250000
# ONGC.BO            152.199997
# POWERGRID.BO       225.399994
# RELIANCE.BO       2337.350098
# SBIN.BO            522.349976
# SUNPHARMA.BO       988.650024
# TCS.BO            3195.699951
# TECHM.BO          1102.000000
# TITAN.BO          2513.500000
# ULTRACEMCO.BO     7633.600098
# ...

# %%
ts.Close.iloc[0]
# Out:
# ASIANPAINT.BO     3046.350098
# AXISBANK.BO        941.450012
# BAJAJ-AUTO.BO     3576.649902
# BAJAJFINSV.BO     1552.400024
# BAJFINANCE.BO     6556.750000
# BHARTIARTL.BO      813.599976
# DRREDDY.BO        4237.750000
# HCLTECH.BO        1039.199951
# HDFC.BO           2652.600098
# HDFCBANK.BO       1629.150024
# HINDUNILVR.BO     2558.500000
# ICICIBANK.BO       903.000000
# INDUSINDBK.BO     1226.699951
# INFY.BO           1524.300049
# ITC.BO             332.750000
# KOTAKBANK.BO      1825.849976
# LT.BO             2088.800049
# M&M.BO            1262.900024
# MARUTI.BO         8406.650391
# NESTLEIND.BO     19563.949219
# NTPC.BO            168.000000
# ONGC.BO            150.399994
# POWERGRID.BO       215.100006
# RELIANCE.BO       2575.149902
# SBIN.BO            612.250000
# SUNPHARMA.BO       997.099976
# TCS.BO            3260.649902
# TECHM.BO          1009.500000
# TITAN.BO          2565.800049
# ULTRACEMCO.BO     7010.250000
# ...

# %%
ts.Close.iloc[-1].div(ts.Close.iloc[0])
# Out:
# ASIANPAINT.BO    0.906659
# AXISBANK.BO      0.906527
# BAJAJ-AUTO.BO    1.088533
# BAJAJFINSV.BO    0.808877
# BAJFINANCE.BO    0.858352
# BHARTIARTL.BO    0.923673
# DRREDDY.BO       1.097280
# HCLTECH.BO       1.046189
# HDFC.BO          0.987899
# HDFCBANK.BO      0.985330
# HINDUNILVR.BO    0.991948
# ICICIBANK.BO     0.970210
# INDUSINDBK.BO    0.874705
# INFY.BO          0.935774
# ITC.BO           1.150263
# KOTAKBANK.BO     0.952789
# LT.BO            1.040789
# M&M.BO           0.912899
# MARUTI.BO        0.988503
# NESTLEIND.BO     0.998372
# NTPC.BO          1.049107
# ONGC.BO          1.011968
# POWERGRID.BO     1.047885
# RELIANCE.BO      0.907656
# SBIN.BO          0.853165
# SUNPHARMA.BO     0.991525
# TCS.BO           0.980081
# TECHM.BO         1.091630
# TITAN.BO         0.979616
# ULTRACEMCO.BO    1.088920
# dtype: float64

# %%
ts.Close.iloc[-1].div(ts.Close.iloc[0]).sub(1)
# Out:
# ASIANPAINT.BO   -0.093341
# AXISBANK.BO     -0.093473
# BAJAJ-AUTO.BO    0.088533
# BAJAJFINSV.BO   -0.191123
# BAJFINANCE.BO   -0.141648
# BHARTIARTL.BO   -0.076327
# DRREDDY.BO       0.097280
# HCLTECH.BO       0.046189
# HDFC.BO         -0.012101
# HDFCBANK.BO     -0.014670
# HINDUNILVR.BO   -0.008052
# ICICIBANK.BO    -0.029790
# INDUSINDBK.BO   -0.125295
# INFY.BO         -0.064226
# ITC.BO           0.150263
# KOTAKBANK.BO    -0.047211
# LT.BO            0.040789
# M&M.BO          -0.087101
# MARUTI.BO       -0.011497
# NESTLEIND.BO    -0.001628
# NTPC.BO          0.049107
# ONGC.BO          0.011968
# POWERGRID.BO     0.047885
# RELIANCE.BO     -0.092344
# SBIN.BO         -0.146835
# SUNPHARMA.BO    -0.008475
# TCS.BO          -0.019919
# TECHM.BO         0.091630
# TITAN.BO        -0.020384
# ULTRACEMCO.BO    0.088920
# dtype: float64

# %%
perf=ts.Close.iloc[-1].div(ts.Close.iloc[0]).sub(1).sort_values(ascending=False)
perf
# Out:
# ITC.BO           0.150263
# DRREDDY.BO       0.097280
# TECHM.BO         0.091630
# ULTRACEMCO.BO    0.088920
# BAJAJ-AUTO.BO    0.088533
# NTPC.BO          0.049107
# POWERGRID.BO     0.047885
# HCLTECH.BO       0.046189
# LT.BO            0.040789
# ONGC.BO          0.011968
# NESTLEIND.BO    -0.001628
# HINDUNILVR.BO   -0.008052
# SUNPHARMA.BO    -0.008475
# MARUTI.BO       -0.011497
# HDFC.BO         -0.012101
# HDFCBANK.BO     -0.014670
# TCS.BO          -0.019919
# TITAN.BO        -0.020384
# ICICIBANK.BO    -0.029790
# KOTAKBANK.BO    -0.047211
# INFY.BO         -0.064226
# BHARTIARTL.BO   -0.076327
# M&M.BO          -0.087101
# RELIANCE.BO     -0.092344
# ASIANPAINT.BO   -0.093341
# AXISBANK.BO     -0.093473
# INDUSINDBK.BO   -0.125295
# BAJFINANCE.BO   -0.141648
# SBIN.BO         -0.146835
# BAJAJFINSV.BO   -0.191123
# dtype: float64

# %%
perf.index.name='Symbol'

# %%
perf.index
# Out:
# Index(['ITC.BO', 'DRREDDY.BO', 'TECHM.BO', 'ULTRACEMCO.BO', 'BAJAJ-AUTO.BO',
#        'NTPC.BO', 'POWERGRID.BO', 'HCLTECH.BO', 'LT.BO', 'ONGC.BO',
#        'NESTLEIND.BO', 'HINDUNILVR.BO', 'SUNPHARMA.BO', 'MARUTI.BO', 'HDFC.BO',
#        'HDFCBANK.BO', 'TCS.BO', 'TITAN.BO', 'ICICIBANK.BO', 'KOTAKBANK.BO',
#        'INFY.BO', 'BHARTIARTL.BO', 'M&M.BO', 'RELIANCE.BO', 'ASIANPAINT.BO',
#        'AXISBANK.BO', 'INDUSINDBK.BO', 'BAJFINANCE.BO', 'SBIN.BO',
#        'BAJAJFINSV.BO'],
#       dtype='object', name='Symbol')

# %%
perf
# Out:
# Symbol
# ITC.BO           0.150263
# DRREDDY.BO       0.097280
# TECHM.BO         0.091630
# ULTRACEMCO.BO    0.088920
# BAJAJ-AUTO.BO    0.088533
# NTPC.BO          0.049107
# POWERGRID.BO     0.047885
# HCLTECH.BO       0.046189
# LT.BO            0.040789
# ONGC.BO          0.011968
# NESTLEIND.BO    -0.001628
# HINDUNILVR.BO   -0.008052
# SUNPHARMA.BO    -0.008475
# MARUTI.BO       -0.011497
# HDFC.BO         -0.012101
# HDFCBANK.BO     -0.014670
# TCS.BO          -0.019919
# TITAN.BO        -0.020384
# ICICIBANK.BO    -0.029790
# KOTAKBANK.BO    -0.047211
# INFY.BO         -0.064226
# BHARTIARTL.BO   -0.076327
# M&M.BO          -0.087101
# RELIANCE.BO     -0.092344
# ASIANPAINT.BO   -0.093341
# AXISBANK.BO     -0.093473
# INDUSINDBK.BO   -0.125295
# BAJFINANCE.BO   -0.141648
# SBIN.BO         -0.146835
# BAJAJFINSV.BO   -0.191123
# dtype: float64

# %%
# df.reset_index()
# df.index=df.Symbol
# df.head()

# %%
df.index
# Out:
# Index(['ASIANPAINT.BO', 'AXISBANK.BO', 'BAJAJ-AUTO.BO', 'BAJFINANCE.BO',
#        'BAJAJFINSV.BO', 'BHARTIARTL.BO', 'DRREDDY.BO', 'HCLTECH.BO', 'HDFC.BO',
#        'HDFCBANK.BO', 'HINDUNILVR.BO', 'ICICIBANK.BO', 'INDUSINDBK.BO',
#        'INFY.BO', 'ITC.BO', 'KOTAKBANK.BO', 'LT.BO', 'M&M.BO', 'MARUTI.BO',
#        'NESTLEIND.BO', 'NTPC.BO', 'ONGC.BO', 'POWERGRID.BO', 'RELIANCE.BO',
#        'SBIN.BO', 'SUNPHARMA.BO', 'TCS.BO', 'TECHM.BO', 'TITAN.BO',
#        'ULTRACEMCO.BO'],
#       dtype='object', name='Symbol')

# %%
df["performance"]=perf
df.head()
# Out:
#                #  ticker Number         Symbol      Companies  \
# Symbol
# ASIANPAINT.BO  1         500820  ASIANPAINT.BO   Asian Paints
# AXISBANK.BO    2         532215    AXISBANK.BO      Axis Bank
# BAJAJ-AUTO.BO  3         532977  BAJAJ-AUTO.BO     Bajaj Auto
# BAJFINANCE.BO  4         500034  BAJFINANCE.BO  Bajaj Finance
# BAJAJFINSV.BO  5         532978  BAJAJFINSV.BO  Bajaj Finserv
#
#                              Sector           Unnamed: 5  performance
# Symbol
# ASIANPAINT.BO                Paints  21 December 2015[4]    -0.093341
# AXISBANK.BO       Banking - Private                  NaN    -0.093473
# BAJAJ-AUTO.BO            Automobile                  NaN     0.088533
# BAJFINANCE.BO        Finance (NBFC)  24 December 2018[5]    -0.141648
# BAJAJFINSV.BO  Finance (Investment)                  NaN    -0.191123

# %%
df.sort_values(by='performance',ascending=False)
# Out:
#                 #  ticker Number         Symbol  \
# Symbol
# ITC.BO         15         500875         ITC.BO
# DRREDDY.BO      7         500124     DRREDDY.BO
# TECHM.BO       28         532755       TECHM.BO
# ULTRACEMCO.BO  30         532538  ULTRACEMCO.BO
# BAJAJ-AUTO.BO   3         532977  BAJAJ-AUTO.BO
# NTPC.BO        21         532555        NTPC.BO
# POWERGRID.BO   23         532898   POWERGRID.BO
# HCLTECH.BO      8         532281     HCLTECH.BO
# LT.BO          17         500510          LT.BO
# ONGC.BO        22         500312        ONGC.BO
# NESTLEIND.BO   20         500790   NESTLEIND.BO
# HINDUNILVR.BO  11         500696  HINDUNILVR.BO
# SUNPHARMA.BO   26         524715   SUNPHARMA.BO
# MARUTI.BO      19         532500      MARUTI.BO
# HDFC.BO         9         500010        HDFC.BO
# HDFCBANK.BO    10         500180    HDFCBANK.BO
# TCS.BO         27         532540         TCS.BO
# TITAN.BO       29         500114       TITAN.BO
# ...

# %% [markdown]
# # Detailed Stock data

# %%
# !pip install yfinance --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
itc=yf.Ticker(ticker='ITC.BO')

# %%
info=pd.Series(itc.get_info()).to_frame().T
info
# Out:
#    symbol twoHundredDayAverageChangePercent fiftyTwoWeekLowChangePercent  \
# 0  ITC.BO                          0.983473                     1.845128
#
#   language regularMarketDayRange regularMarketDayHigh  \
# 0    en-US        380.0 - 384.45               384.45
#
#   twoHundredDayAverageChange askSize twoHundredDayAverage bookValue  ...  \
# 0                  190.37538       0            193.57463    53.146  ...
#
#   regularMarketPrice marketState customPriceAlertConfidence    ask  \
# 0             383.95     REGULAR                        LOW  384.0
#
#   epsTrailingTwelveMonths    bid triggerable priceToBook     longName  \
# 0                  11.767  383.8       False    7.224439  ITC Limited
#
#   trailingPegRatio
# 0             None
#
# [1 rows x 63 columns]

# %%
symbols
# Out:
# ['ASIANPAINT.BO',
#  'AXISBANK.BO',
#  'BAJAJ-AUTO.BO',
#  'BAJFINANCE.BO',
#  'BAJAJFINSV.BO',
#  'BHARTIARTL.BO',
#  'DRREDDY.BO',
#  'HCLTECH.BO',
#  'HDFC.BO',
#  'HDFCBANK.BO',
#  'HINDUNILVR.BO',
#  'ICICIBANK.BO',
#  'INDUSINDBK.BO',
#  'INFY.BO',
#  'ITC.BO',
#  'KOTAKBANK.BO',
#  'LT.BO',
#  'M&M.BO',
#  'MARUTI.BO',
#  'NESTLEIND.BO',
#  'NTPC.BO',
#  'ONGC.BO',
#  'POWERGRID.BO',
#  'RELIANCE.BO',
#  'SBIN.BO',
#  'SUNPHARMA.BO',
#  'TCS.BO',
#  'TECHM.BO',
#  'TITAN.BO',
#  'ULTRACEMCO.BO']

# %%
cs=pd.DataFrame()
cs
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
count=1
for symbol in symbols:
  try:
    info=pd.Series(yf.Ticker(ticker=symbol).get_info()).to_frame().T
    cs=pd.concat([cs,info])
    print(count,end='\r')
    # print('{}'.format(symbol))
    count+=1
  except Exception as e:
    print('{} not found'.format(symbol))
print('Donwload complete')
# Out:
# Donwload complete

# %%
cs.set_index('symbol',inplace=True)

# %%
cs.index.name='Symbol'
cs.head()
# Out:
#               twoHundredDayAverageChangePercent fiftyTwoWeekLowChangePercent  \
# Symbol
# ASIANPAINT.BO                          0.235416                     0.927332
# AXISBANK.BO                            0.564635                     2.017544
# BAJAJ-AUTO.BO                          0.198492                     1.165579
# BAJFINANCE.BO                          0.349901                     2.151814
# BAJAJFINSV.BO                          -0.82946                     0.012478
#
#               language regularMarketDayRange regularMarketDayHigh  \
# Symbol
# ASIANPAINT.BO    en-US     2747.45 - 2772.65              2772.65
# AXISBANK.BO      en-US         848.7 - 861.0                861.0
# BAJAJ-AUTO.BO    en-US      3801.75 - 3907.0               3907.0
# BAJFINANCE.BO    en-US       5586.1 - 5689.0               5689.0
# BAJAJFINSV.BO    en-US      1250.15 - 1266.9               1266.9
#
#               twoHundredDayAverageChange askSize twoHundredDayAverage  \
# Symbol
# ...

# %%
cs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, ASIANPAINT.BO to ULTRACEMCO.BO
# Data columns (total 70 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   twoHundredDayAverageChangePercent  30 non-null     object
#  1   fiftyTwoWeekLowChangePercent       30 non-null     object
#  2   language                           30 non-null     object
#  3   regularMarketDayRange              30 non-null     object
#  4   regularMarketDayHigh               30 non-null     object
#  5   twoHundredDayAverageChange         30 non-null     object
#  6   askSize                            30 non-null     object
#  7   twoHundredDayAverage               30 non-null     object
#  8   bookValue                          29 non-null     object
#  9   marketCap                          30 non-null     object
#  10  fiftyTwoWeekHighChange             30 non-null     object
# ...

# %% [markdown]
# # Equity Analysis & Comparision

# %%
cs.priceToBook.sort_values(ascending=False)
# Out:
# Symbol
# INFY.BO          629.73987
# HCLTECH.BO       382.03867
# NESTLEIND.BO      83.41267
# TITAN.BO         33.472454
# ASIANPAINT.BO    26.130327
# HINDUNILVR.BO    12.835401
# TCS.BO           12.652986
# BAJFINANCE.BO    10.429774
# ITC.BO            7.224439
# BHARTIARTL.BO     6.700644
# ULTRACEMCO.BO     5.621065
# SUNPHARMA.BO      5.205099
# BAJAJ-AUTO.BO     5.186186
# MARUTI.BO          5.07023
# KOTAKBANK.BO      4.979029
# DRREDDY.BO        4.732802
# HDFCBANK.BO       4.621638
# LT.BO             4.560431
# ICICIBANK.BO      4.504782
# TECHM.BO          4.406265
# HDFC.BO           3.602368
# RELIANCE.BO       3.048649
# AXISBANK.BO       2.775142
# INDUSINDBK.BO      2.13093
# POWERGRID.BO      1.828582
# SBIN.BO           1.789987
# NTPC.BO           1.459156
# ONGC.BO           0.919043
# BAJAJFINSV.BO     0.643514
# M&M.BO                 NaN
# Name: priceToBook, dtype: object

# %%
cs.loc['ITC.BO','bookValue']
# Out:
# 53.146

# %%
cs.loc['ITC.BO','priceToBook']
# Out:
# 7.2244387

# %%
cs.trailingAnnualDividendYield
# Out:
# Symbol
# ASIANPAINT.BO    0.004334
# AXISBANK.BO      0.001186
# BAJAJ-AUTO.BO    0.030929
# BAJFINANCE.BO    0.001777
# BAJAJFINSV.BO    0.004015
# BHARTIARTL.BO     0.00269
# DRREDDY.BO       0.005477
# HCLTECH.BO       0.000137
# HDFC.BO          0.008068
# HDFCBANK.BO      0.009443
# HINDUNILVR.BO    0.011074
# ICICIBANK.BO     0.001175
# INDUSINDBK.BO    0.007096
# INFY.BO           0.00021
# ITC.BO           0.026532
# KOTAKBANK.BO     0.000465
# LT.BO            0.008384
# M&M.BO                NaN
# MARUTI.BO        0.007238
# NESTLEIND.BO     0.006085
# NTPC.BO          0.018098
# ONGC.BO          0.033467
# POWERGRID.BO     0.044954
# RELIANCE.BO      0.002908
# SBIN.BO               NaN
# SUNPHARMA.BO     0.004038
# TCS.BO           0.012747
# TECHM.BO         0.013873
# TITAN.BO          0.00159
# ULTRACEMCO.BO    0.001717
# Name: trailingAnnualDividendYield, dtype: object

# %%
cs.loc['ITC.BO','trailingAnnualDividendYield']
# Out:
# 0.026532479

# %%
cs.trailingAnnualDividendYield.plot(kind='bar')
# Out:
# <Axes: xlabel='Symbol'>

# %%
df.drop('Unnamed: 5',axis=1,inplace=True)
df.head()
# Out:
#                #  ticker Number         Symbol      Companies  \
# Symbol
# ASIANPAINT.BO  1         500820  ASIANPAINT.BO   Asian Paints
# AXISBANK.BO    2         532215    AXISBANK.BO      Axis Bank
# BAJAJ-AUTO.BO  3         532977  BAJAJ-AUTO.BO     Bajaj Auto
# BAJFINANCE.BO  4         500034  BAJFINANCE.BO  Bajaj Finance
# BAJAJFINSV.BO  5         532978  BAJAJFINSV.BO  Bajaj Finserv
#
#                              Sector  performance
# Symbol
# ASIANPAINT.BO                Paints    -0.093341
# AXISBANK.BO       Banking - Private    -0.093473
# BAJAJ-AUTO.BO            Automobile     0.088533
# BAJFINANCE.BO        Finance (NBFC)    -0.141648
# BAJAJFINSV.BO  Finance (Investment)    -0.191123

# %%
df['Price_to_Book']=cs.priceToBook
df['Forward_PE']=cs.forwardPE
df['Divident_Yeild_Annual']=cs.trailingAnnualDividendYield
df.head()
# Out:
#                #  ticker Number         Symbol      Companies  \
# Symbol
# ASIANPAINT.BO  1         500820  ASIANPAINT.BO   Asian Paints
# AXISBANK.BO    2         532215    AXISBANK.BO      Axis Bank
# BAJAJ-AUTO.BO  3         532977  BAJAJ-AUTO.BO     Bajaj Auto
# BAJFINANCE.BO  4         500034  BAJFINANCE.BO  Bajaj Finance
# BAJAJFINSV.BO  5         532978  BAJAJFINSV.BO  Bajaj Finserv
#
#                              Sector  performance Price_to_Book Forward_PE  \
# Symbol
# ASIANPAINT.BO                Paints    -0.093341     26.130327        NaN
# AXISBANK.BO       Banking - Private    -0.093473      2.775142  21.944374
# BAJAJ-AUTO.BO            Automobile     0.088533      5.186186        NaN
# BAJFINANCE.BO        Finance (NBFC)    -0.141648     10.429774  66.540375
# BAJAJFINSV.BO  Finance (Investment)    -0.191123      0.643514   51.20348
#
#               Divident_Yeild_Annual
# Symbol
# ASIANPAINT.BO              0.004334
# AXISBANK.BO                0.001186
# ...

# %%
df.drop(['#','ticker Number'],axis=1,inplace=True)
df.head()
# Out:
#                       Symbol      Companies                Sector  \
# Symbol
# ASIANPAINT.BO  ASIANPAINT.BO   Asian Paints                Paints
# AXISBANK.BO      AXISBANK.BO      Axis Bank     Banking - Private
# BAJAJ-AUTO.BO  BAJAJ-AUTO.BO     Bajaj Auto            Automobile
# BAJFINANCE.BO  BAJFINANCE.BO  Bajaj Finance        Finance (NBFC)
# BAJAJFINSV.BO  BAJAJFINSV.BO  Bajaj Finserv  Finance (Investment)
#
#                performance Price_to_Book Forward_PE Divident_Yeild_Annual
# Symbol
# ASIANPAINT.BO    -0.093341     26.130327        NaN              0.004334
# AXISBANK.BO      -0.093473      2.775142  21.944374              0.001186
# BAJAJ-AUTO.BO     0.088533      5.186186        NaN              0.030929
# BAJFINANCE.BO    -0.141648     10.429774  66.540375              0.001777
# BAJAJFINSV.BO    -0.191123      0.643514   51.20348              0.004015

# %% [markdown]
# # New Section
