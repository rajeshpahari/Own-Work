# %% [markdown]
# <a href="https://colab.research.google.com/github/rajeshpahari/Own-Work/blob/main/005_Financial_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Finanacial Data Analysis & Performance Evaluation

# %% [markdown]
# # New Section

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
pd.options.display.float_format='{:.4f}'.format
# Out:
# <ipython-input-1-8cb3316f44be>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
import yfinance as yf

# %%
url='https://en.wikipedia.org/wiki/NIFTY_50'

# %%
df=pd.read_html(url)[2]

# %%
symbol=df.Symbol+'.NS'
symbol=symbol.to_list()
symbol
# Out:
# ['ADANIENT.NS',
#  'ADANIPORTS.NS',
#  'APOLLOHOSP.NS',
#  'ASIANPAINT.NS',
#  'AXISBANK.NS',
#  'BAJAJ-AUTO.NS',
#  'BAJFINANCE.NS',
#  'BAJAJFINSV.NS',
#  'BPCL.NS',
#  'BHARTIARTL.NS',
#  'BRITANNIA.NS',
#  'CIPLA.NS',
#  'COALINDIA.NS',
#  'DIVISLAB.NS',
#  'DRREDDY.NS',
#  'EICHERMOT.NS',
#  'GRASIM.NS',
#  'HCLTECH.NS',
#  'HDFC.NS',
#  'HDFCBANK.NS',
#  'HDFCLIFE.NS',
#  'HEROMOTOCO.NS',
#  'HINDALCO.NS',
#  'HINDUNILVR.NS',
#  'ICICIBANK.NS',
#  'INDUSINDBK.NS',
#  'INFY.NS',
#  'ITC.NS',
#  'JSWSTEEL.NS',
#  'KOTAKBANK.NS',
#  'LT.NS',
#  'M&M.NS',
#  'MARUTI.NS',
#  'NESTLEIND.NS',
#  'NTPC.NS',
#  'ONGC.NS',
#  'POWERGRID.NS',
#  'RELIANCE.NS',
#  'SBILIFE.NS',
#  'SBIN.NS',
#  'SUNPHARMA.NS',
#  'TATAMOTORS.NS',
#  'TATASTEEL.NS',
#  'TCS.NS',
#  'TATACONSUM.NS',
#  'TECHM.NS',
#  'TITAN.NS',
#  'ULTRACEMCO.NS',
#  'UPL.NS',
#  'WIPRO.NS']

# %%
cs=pd.DataFrame()
cs
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# help(yf.Ticker)

# %%
# for i in symbol:
#   try:
#     info=pd.Series(yf.Ticker(ticker=i).get_info()).to_frame().T
#     cs=pd.concat([cs,info])
#     print('{} is recived'.format(i))
#   except Exception as e:
#     print('{} is not available'.format(i))

# print('Download is completed')

# %%
cs=yf.download(tickers=symbol,period='1y',actions=True)
# Out:
# [*********************100%***********************]  50 of 50 completed

# %%
cs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 249 entries, 2022-04-04 to 2023-04-03
# Columns: 400 entries, ('Adj Close', 'ADANIENT.NS') to ('Volume', 'WIPRO.NS')
# dtypes: float64(350), int64(50)
# memory usage: 780.1 KB

# %%
cs.Close['BAJFINANCE.NS'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
cs.Close.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %%
close=cs.Close

# %%
close
# Out:
#             ADANIENT.NS  ADANIPORTS.NS  APOLLOHOSP.NS  ASIANPAINT.NS  \
# Date
# 2022-04-04    2065.8501       818.5500      4564.9502      3118.0000
# 2022-04-05    2139.8501       848.0500      4554.2500      3140.8000
# 2022-04-06    2160.0000       849.8500      4511.7500      3154.0000
# 2022-04-07    2099.0500       817.4000      4536.5000      3155.0000
# 2022-04-08    2170.9500       839.3000      4606.1499      3206.2500
# ...                 ...            ...            ...            ...
# 2023-03-27    1723.0500       629.1000      4318.1001      2803.7500
# 2023-03-28    1600.8500       593.4000      4333.6001      2784.4500
# 2023-03-29    1740.4000       636.6500      4363.0000      2770.5000
# 2023-03-31    1750.4500       631.9000      4310.8999      2761.6499
# 2023-04-03    1719.7000       626.2000      4278.6001      2747.6499
#
#             AXISBANK.NS  BAJAJ-AUTO.NS  BAJAJFINSV.NS  BAJFINANCE.NS  \
# Date
# ...

# %%
close.iloc[:,0].div(close.iloc[0,0])
# Out:
# Date
# 2022-04-04   1.0000
# 2022-04-05   1.0358
# 2022-04-06   1.0456
# 2022-04-07   1.0161
# 2022-04-08   1.0509
#               ...
# 2023-03-27   0.8341
# 2023-03-28   0.7749
# 2023-03-29   0.8425
# 2023-03-31   0.8473
# 2023-04-03   0.8324
# Name: ADANIENT.NS, Length: 249, dtype: float64

# %%
close.iloc[0]
# Out:
# ADANIENT.NS      2065.8501
# ADANIPORTS.NS     818.5500
# APOLLOHOSP.NS    4564.9502
# ASIANPAINT.NS    3118.0000
# AXISBANK.NS       784.1000
# BAJAJ-AUTO.NS    3763.6499
# BAJAJFINSV.NS    1719.6350
# BAJFINANCE.NS    7490.6499
# BHARTIARTL.NS     767.8000
# BPCL.NS           380.2000
# BRITANNIA.NS     3270.0000
# CIPLA.NS         1027.8000
# COALINDIA.NS      187.7500
# DIVISLAB.NS      4497.6001
# DRREDDY.NS       4317.1499
# EICHERMOT.NS     2508.9500
# GRASIM.NS        1679.7000
# HCLTECH.NS       1187.0500
# HDFC.NS          2680.0500
# HDFCBANK.NS      1656.8000
# HDFCLIFE.NS       571.8000
# HEROMOTOCO.NS    2311.7500
# HINDALCO.NS       587.5000
# HINDUNILVR.NS    2128.4500
# ICICIBANK.NS      746.6000
# INDUSINDBK.NS     987.2000
# INFY.NS          1882.9500
# ITC.NS            255.4500
# JSWSTEEL.NS       732.7000
# KOTAKBANK.NS     1836.0500
# LT.NS            1826.3500
# M&M.NS            833.7000
# MARUTI.NS        7774.7998
# NESTLEIND.NS    17820.1504
# ...

# %%
norm=close.div(close.iloc[0]).mul(100)
norm
# Out:
#             ADANIENT.NS  ADANIPORTS.NS  APOLLOHOSP.NS  ASIANPAINT.NS  \
# Date
# 2022-04-04     100.0000       100.0000       100.0000       100.0000
# 2022-04-05     103.5821       103.6039        99.7656       100.7312
# 2022-04-06     104.5574       103.8238        98.8346       101.1546
# 2022-04-07     101.6071        99.8595        99.3768       101.1867
# 2022-04-08     105.0875       102.5350       100.9025       102.8303
# ...                 ...            ...            ...            ...
# 2023-03-27      83.4063        76.8554        94.5925        89.9214
# 2023-03-28      77.4911        72.4940        94.9320        89.3024
# 2023-03-29      84.2462        77.7778        95.5761        88.8550
# 2023-03-31      84.7327        77.1975        94.4348        88.5712
# 2023-04-03      83.2442        76.5011        93.7272        88.1222
#
#             AXISBANK.NS  BAJAJ-AUTO.NS  BAJAJFINSV.NS  BAJFINANCE.NS  \
# Date
# ...

# %%
norm.dropna().plot(figsize=(12,8),logy=True)
# Out:
# <Axes: xlabel='Date'>
